# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayaprakash012/Oops-Concept-in-Python-with-Example/blob/main/OPPS_CONCEPT_IN_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class demo:
    def greet(self):
        print("object created successfully")
d = demo()
d.greet()
# Out:
# object created successfully

# %%
class demo:
    def greet(self, name):
        print(f"object created successfully {name}")
d = demo()
d.greet("jitu")
# Out:
# object created successfully jitu

# %%
class demo:
    def __init__(self,name):
      self.name = name
    def greet(self):
        print(f"object created successfully {self.name}")
d = demo("jitu")
d.greet()
# Out:
# object created successfully jitu

# %%
#manual input
class Student:
    def __init__(self, name, roll_no, sec, city):
        self.name = name
        self.roll_no = roll_no
        self.sec = sec
        self.city = city


    def details(self):
        print(f"Hello, I am {self.name}")
        print(f"my  {self.roll_no}")
        print(f"I am from {self.sec}")
        print(f"my hometown is {self.city}")

s1 = Student("jaya prakash", 586, "cse", "chennai")
s1.details()
# Out:
# Hello, I am jaya prakash
# my  586
# I am from cse
# my hometown is chennai

# %%
# User Input
class Student:
    def __init__(self, name, roll_number, section, city):
        self.name = name
        self.roll_number = roll_number
        self.section = section
        self.city = city
    def display(self):
        print("Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Section:", self.section)
        print("City:", self.city)
name = input("Enter student's name: ")
roll_number = input("Enter student's roll number: ")
section = input("Enter student's section: ")
city = input("Enter student's city: ")
student = Student(name, roll_number, section, city)
student.display()
# Out:
# Enter student's name: jitu
# Enter student's roll number: 23cse586
# Enter student's section: i
# Enter student's city: kendrapara
# Name: jitu
# Roll Number: 23cse586
# Section: i
# City: kendrapara

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def display(self):
      print("Name:",self.name)
      print("Age:",self.age)
s = student("jitu",20)
s.display()
# Out:
# Name: jitu
# Age: 20

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def display(self):
      print("Name:",self.name)
      print("Age:",self.age)
s = student("jitu",20)
s.display()
#acess variables outside the class
print("acess outside class",s.name)
print(s.age)
#delete variable outside the class
del s.name
# Out:
# Name: jitu
# Age: 20
# acess outside class jitu
# 20

# %%
class student:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def display(self):
      print("Name:",self.name)
      print("Age:",self.age)
s = student("jitu",20)
s.display()
#acess variables outside the class
print("acess outside class",s.name)
print(s.age)
#delete variable outside the class
del s.name
#print(s.name)
#modify variable
print("Before Update",s.age)
s.age = 40
print("After Update",s.age)
#add new variables to existing class
s.city="BBSR"
print(s.city)
# Out:
# Name: jitu
# Age: 20
# acess outside class jitu
# 20
# Before Update 20
# After Update 40
# BBSR

# %%
#single level inheritance
class Parent:
    def display(self):
        print("This is parent class")
class Child(Parent):
    pass
obj = Child()
obj.display()
# Out:
# This is parent class

# %%
class Parent:
    def show(self):
        print("Parent class")

class Child(Parent):
    def hello(self):
        print("Child class")

obj = Child()
obj.show()
obj.hello()
# Out:
# Parent class
# Child class

# %%
class Parent:
    def show(self):
        print("this is Parent class")

class Child(Parent):
    def display(self):
        print(" this is Child class")

obj = Child()
obj.show()
obj.display()
# Out:
# this is Parent class
#  this is Child class

# %%
class Parent:
    def __init__(self):
        print("This is Parent class constructor")

class Child(Parent):
    def __init__(self):
        super().__init__()
        print("This is Child class constructor")

c = Child()
# Out:
# This is Parent class constructor
# This is Child class constructor

# %%
class Parent:
    def __init__(self):
        print("This is Parent class constructor")

class Child(Parent):
    def __init__(self):

        print("This is Child class constructor")
        super().__init__()
c = Child()
# Out:
# This is Child class constructor
# This is Parent class constructor

# %%
class Person:
  def info(self):
    print("my name is jitu")
class Teacher(Person):
  def teach(self):
    print("I teach student")
class SubjectTeacher(Teacher):
  def subject(self):
    print("I teach BGMI")


st = SubjectTeacher()
st.info()
st.teach()
st.subject()
# Out:
# my name is jitu
# I teach student
# I teach BGMI

# %%
#Multilevel inheritance
class grandfather:
  def info(self):
    print("grandfather")
class father(grandfather):
  def birth(self):
    print("father")
class grandparents(father):
  def me(self):
    print("my birth")
st = grandparents()
st.info()
st.birth()
st.me()
# Out:
# grandfather
# father
# my birth

# %%
#multiple inheritance
class Father:
    def skills(self):
        print("Gardening, Carpentry")

class Mother:
    def skills(self):
        print("Cooking, Painting")

class Child(Father, Mother):
    pass

c = Child()
c.skills()
# Out:
# Gardening, Carpentry

# %%
#Heirarchical Inheritance
class Parent:
    def show(self):
        print("This is Parent class")

class Child1(Parent):
    def display1(self):
        print("This is Child1 class")

class Child2(Parent):
    def display2(self):
        print("This is Child2 class")

c1 = Child1()
c2 = Child2()

c1.show()
c1.display1()

c2.show()
c2.display2()
# Out:
# This is Parent class
# This is Child1 class
# This is Parent class
# This is Child2 class

# %%
#polymorphism
#polymirphism is two types(1)compile time:before execution example:-methodoverloading,syntax error(2)runtime error:-logical error,after execution
#method overloading:-same method,different parameter
#mothod overriding:-same method,sameparameter
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")


a = Dog()
b = Cat()

a.sound()
b.sound()
# Out:
# Dog barks
# Cat meows

# %%
#ENCAPSULATION
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # Private variable

    def deposit(self, amount):
        self.__balance += amount

    def get_balance(self):
        return self.__balance


# Creating object
account = BankAccount(1000)

account.deposit(500)

print("Balance:", account.get_balance())
# Out:
# Balance: 1500

# %%
from abc import ABC, abstractmethod

class Shape(ABC):   # Abstract class
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle(5, 4)
print("Area:", r.area())
# Out:
# Area: 20

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

c1 = Car("Toyota")
print(c1.brand)
# Out:
# Toyota

# %%
class Student:
    def __init__(self, name):
        self.name = name

s = Student("Jaya")
print(s.name)
# Out:
# Jaya

# %%
class Person:
    def greet(self):
        print("Hello!")

p = Person()
p.greet()
# Out:
# Hello!

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# %%
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    pass

class Child2(Parent):
    pass

# %%
class Father:
    def skill(self):
        print("Driving")

class Mother:
    def talent(self):
        print("Cooking")

class Child(Father, Mother):
    pass

c = Child()
c.skill()
c.talent()
# Out:
# Driving
# Cooking

# %%
#compile time polymorohism example
print(len([1,2,3,4]))
print(len("jitu"))
print(len({13, 42, 44, 67}))
# Out:
# 4
# 4
# 4

# %%
#method overloading
def add(a,b=10):
  print(a+b)
add(10,30)
add(20)
# Out:
# 40
# 30

# %%
#method overrididng
class payment:
  def pay(self):
    pass
class UPI(payment):
  def pay(self):
    print("Payment will be done by UPI")
class Cash(payment):
  def pay(self):
    print("payment done by cash")
class GooglePay(payment):
  def pay(self):
    print("payment will be done by GooglePlay")
p = [UPI(),Cash(),GooglePay()]
for i in p:
  i.pay()
# Out:
# Pyment will be done by UPI
# payment done by cash
# payment will be done by GooglePlay

# %%
class Vehicle:
  def move(self):
    pass
class Bike(Vehicle):
  def move(self):
    print("Bike is a vehicle")
class Scotty(Vehicle):
  def move(self):
    print("Scotty is a vehicle")
class Car(Vehicle):
  def move(self):
    print("Car is a vehicle")
v = [Bike(),Scotty(),Car()]
for i in v:
  i.move()
# Out:
# bike is a vehicle
# Scotty is a vehicle
# Car is a vehicle

# %%
#concatenation operation
class student:
  def __init__(self,marks):
    self.marks=marks
  def __add__(self,other):
    return self.marks+other.marks
s = student(30)
s1 = student(50)
print(s+s1)
# Out:
# 80

# %%
#RunTime Polymorphism
class dog:
  def sound(self):
    print("dog barks")
class cat:
  def sound(self):
    print("cat meow")
def make_sound(animal):
  animal.sound()
make_sound(dog())
make_sound(cat())
# Out:
# dog barks
# cat meow

# %%
class animal:
  def sound(self):
    print("Animal Make sound")
class Dog(animal):
  def sound(self):
    super().sound()
    print("dog barks")
class cat(animal):
  def sound(self):
    super().sound()
    print("cat meow")
d = Dog
d.sound
print("")
c = cat()
c.sound()
# Out:
# Animal Make sound
# cat meow

# %%
#Hotel Management System using Inheritance they have class like veg,non veg,sea food ,drinks ,desserts including the menu and bill generation
class Menu:
    def __init__(self):
        self.menu_items = {
            "veg": {"paneer butter masala": 150, "dal makhani": 100},
            "non_veg": {"chicken curry": 200, "mutton curry": 250},
            "sea_food": {"fish curry": 180, "prawn curry": 220},
            "drinks": {"coke": 50, "lemonade": 40},
            "desserts": {"gulab jamun": 80, "ice cream": 60}
        }
    def display_menu(self):
        print("Menu:")
        for category, items in self.menu_items.items():
            print(f"{category.capitalize()}:")
            for item, price in items.items():
                print(f" - {item}: {price} INR")
class Bill(Menu):
    def __init__(self):
        super().__init__()
        self.order = []
    def add_to_order(self, category, item):
        if category in self.menu_items and item in self.menu_items[category]:
            self.order.append((item, self.menu_items[category][item]))
            print(f"Added {item} to order.")
        else:
            print("Item not found in menu.")
    def generate_bill(self):
        total = sum(price for item, price in self.order)
        print("\nBill Summary:")
        for item, price in self.order:
            print(f"{item}: {price} INR")
        print(f"Total: {total} INR")

bill = Bill()
bill.display_menu()
bill.add_to_order("veg", "paneer butter masala")
bill.add_to_order("non_veg", "chicken curry")
bill.add_to_order("drinks", "coke")
bill.generate_bill()
# Out:
# Menu:
# Veg:
#  - paneer butter masala: 150 INR
#  - dal makhani: 100 INR
# Non_veg:
#  - chicken curry: 200 INR
#  - mutton curry: 250 INR
# Sea_food:
#  - fish curry: 180 INR
#  - prawn curry: 220 INR
# Drinks:
#  - coke: 50 INR
#  - lemonade: 40 INR
# Desserts:
#  - gulab jamun: 80 INR
#  - ice cream: 60 INR
# Added paneer butter masala to order.
# Added chicken curry to order.
# Added coke to order.
#
# Bill Summary:
# paneer butter masala: 150 INR
# chicken curry: 200 INR
# coke: 50 INR
# Total: 400 INR

# %%
class vehicle:
  def start(self):
    print("Vehicle Start")


class car(vehicle):
  def start (self):
    super().start()
    print("Car starts by Key")
class bike(vehicle):
  def start(self):
    super().start()
    print("bike stars by kick")
class scotty(vehicle):
  def start (self):
    super().start()
    print("Scotty starts by switch")
c = car()
c.start()
print()
b = bike()
b.start()
# Out:
# Vehicle Start
# Car starts by Key
#
# Vehicle Start
# bike stars by kick

# %%
#abstraction in python
from abc import ABC, abstractmethod
class vehicle(ABC):
    @abstractmethod
    def start(self):
        pass
    def stop(self):
        print("Vehicle stopped.")
class Car(vehicle):
    def start(self):
        print("Car started.")
class Bike(vehicle):
    def start(self):
        print("Bike started.")
car = Car()
car.start()
car.stop()
bike = Bike()
bike.start()
bike.stop()
# Out:
# Car started.
# Vehicle stopped.
# Bike started.
# Vehicle stopped.

# %%
from abc import ABC, abstractmethod
class Restaurant(ABC):
    @abstractmethod
    def menu(self):
        pass
    @abstractmethod
    def bill(self, amount):
        pass
class VegRestaurant(Restaurant):
    def menu(self):
        print("Veg Menu: Idli, Dosa, Paneer Curry")
    def bill(self, amount):
        print("Your total veg bill is:", amount)
class NonVegRestaurant(Restaurant):
    def menu(self):
        print("Non-Veg Menu: Chicken Biryani, Mutton Curry")
    def bill(self, amount):
        print("Your total non-veg bill is:", amount)
veg = VegRestaurant()
veg.menu()
veg.bill(250)
print()
nonveg = NonVegRestaurant()
nonveg.menu()
nonveg.bill(500)
# Out:
# Veg Menu: Idli, Dosa, Paneer Curry
# Your total veg bill is: 250
#
# Non-Veg Menu: Chicken Biryani, Mutton Curry
# Your total non-veg bill is: 500
